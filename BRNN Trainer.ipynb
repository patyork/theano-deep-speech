# %%
__author__ = 'pat'
import numpy as np
import math
import time
from itertools import groupby
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import cPickle as pickle
import theano

import brnn_stacked as nn
# Out:
# Using gpu device 0: GeForce GTX 980

# %%
def str_to_seq(str):
    seq = []
    for c in str:
        val = ord(c)
        if val==32:
            val = 26
        elif val==39:
            val=27
        elif val==45:
            val=28
        else:
            val-=97
        seq.append(val)
    return seq
    

def seq_to_str(seq):
    str = ''
    for elem in seq:
        if elem==26:
            str += ' '
        elif elem==27:
            str += '\''
        elif elem==28:
            str += '-'
        elif elem==29:
            pass
        else:
            str += chr(elem+97)
    return str
    

# Remove consecutive symbols and blanks
def F(pi, blank):
    return [a for a in [key for key, _ in groupby(pi)] if a != blank]
    

# Insert blanks between unique symbols, and at the beginning and end
def make_l_prime(l, blank):
    result = [blank] * (len(l) * 2 + 1)
    result[1::2] = l
    return result
    
    
def log_it(f, epoch=None, error=None, etime=None, samples=None, nan=False, etc=None):
    s5 = '&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'
    if epoch is not None:
        message = time.strftime('%H:%M:%S') + '\tEpoch: ' + str(epoch) + '\tAvg. Error: ' + str(error / samples) + '\tin ' + str(etime) + 's\t' +str(samples) + ' samples\tSamples/sec: ' + str(samples/etime) + '\tApprox. Speed: ' + str(samples * 5 / etime) + 'x real-time'
        print '\n', message, '\n'
        f.write(message.replace('\t', s5) + '<br />')
    elif nan:
        print time.strftime('%H:%M:%S') + '\n========\nHIT NAN=======\nInvalidating Epoch\n===========\n'
        f.write('<br />' + time.strftime('%H:%M:%S') + '\n========\nHIT NAN=======\nInvalidating Epoch\n===========\n\n<br />')
        
    else:
        print etc
        f.write(time.strftime('%H:%M:%S') +s5+ etc.replace('\n', '<br />').replace('\t', s5) + '<br />')

# %%
# Load samples
f = open('win3_l35.pkl', 'rb')
samples = pickle.load(f)
f.close()

samples_sorted = sorted(samples, key=lambda s: len(s[0]))
lens = [len(s[0]) for s in samples_sorted]
lp_lens = [key for key, _ in groupby(lens)]

batch_dict = {}
for length in lp_lens:
    # Get samples of length
    sample_of_len = []
    label_of_len = []
    for s in samples:
        if len(s[0]) == length:
            sample_of_len.append(np.asarray(s[1], dtype=theano.config.floatX))
            label_of_len.append(np.asarray(s[0], dtype='int32'))

    pad_to = np.max([s.shape[0] for s in sample_of_len])
    padded = []
    for s in sample_of_len:

        pad = np.zeros((pad_to-s.shape[0], s.shape[1]))
        padded.append( np.concatenate((s, pad), axis=0))

    batch_dict[length] = (np.asarray(label_of_len, dtype='int32'), np.asarray(padded, dtype=theano.config.floatX))

# %%
visual_samples_y = batch_dict[lp_lens[5]][0][0:10]
visual_samples_x = batch_dict[lp_lens[5]][1][0:10]

print visual_samples_y.shape, visual_samples_x.shape
print [seq_to_str(s) for s in visual_samples_y]
# Out:
# (10, 7) (10, 57, 560)
# [' go', ' no', ' no', ' go', ' go', ' no', ' go', ' no', ' no', ' go']

# %%
alphabet = np.arange(29) #[a,....,z, space, ', -]

# PARAMETERS
epoch_size = 100        # mini-batches per epoch (model is stored at the end of this many mini-batches)
batch_size = 10        # mini-batch size

# HYPER-PARAMETERS
learning_rate = .01
momentum_coefficient = .25

# Automatically Generated Parameters
alphabet_len = len(alphabet)
input_dim = visual_samples_x.shape[2]


net = nn.Network()
rng = np.random.RandomState(int(time.time()))


duration = time.time()
network = net.create_network(input_dim, alphabet_len+1, batch_size=batch_size, learning_rate=learning_rate, momentum=momentum_coefficient)
print 'Network compiled in %.3fs' % (time.time() - duration)
# Out:
# Network compiled in 147.406s
# /usr/local/lib/python2.7/dist-packages/theano/scan_module/scan_perform_ext.py:133: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility
#   from scan_perform.scan_perform import *

# %%
print visual_samples_x.nbytes
print visual_samples_y.nbytes
# Out:
# 1276800
# 280

# %%
for i in np.arange(10):
    duration = time.time()
    new_shape = (visual_samples_x.shape[0]*visual_samples_x.shape[1], input_dim)
    output = network.trainer(visual_samples_x.reshape(new_shape), visual_samples_y, 0.1)[0]

    print output, time.time() - duration
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-9b35dfd2ce76> in <module>()
#       2     duration = time.time()
#       3     new_shape = (visual_samples_x.shape[0]*visual_samples_x.shape[1], input_dim)
# ----> 4     output = network.trainer(visual_samples_x.reshape(new_shape), visual_samples_y, 0.1)[0]
#       5
#       6     print output, time.time() - duration
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     604                         self.fn.nodes[self.fn.position_of_error],
#     605                         self.fn.thunks[self.fn.position_of_error],
# --> 606                         storage_map=self.fn.storage_map)
#     607                 else:
#     608                     # For the c linker We don't have access from
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# MemoryError: Error allocating 243269632 bytes of device memory (out of memory).
# Apply node that caused the error: GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0, Shape_i{1}.0)
# Inputs types: [CudaNdarrayType(float32, scalar), TensorType(int64, scalar), TensorType(int64, scalar), TensorType(int64, scalar)]
# Inputs shapes: [(), (), (), ()]
# Inputs strides: [(), (), (), ()]
# Inputs values: [<CudaNdarray object at 0x7f7b78f53370>, array(58), array(1024), array(1024)]
#
# Debugprint of the apply node:
# GpuAlloc{memset_0=True} [@A] <CudaNdarrayType(float32, 3D)> ''
#  |CudaNdarrayConstant{0.0} [@B] <CudaNdarrayType(float32, scalar)>
#  |Elemwise{add,no_inplace} [@C] <TensorType(int64, scalar)> ''
#  | |TensorConstant{1} [@D] <TensorType(int64, scalar)>
#  | |Shape_i{0} [@E] <TensorType(int64, scalar)> ''
#  |   |Reshape{3} [@F] <TensorType(float64, 3D)> ''
#  |     |Elemwise{mul,no_inplace} [@G] <TensorType(float64, matrix)> ''
#  |     | |HostFromGpu [@H] <TensorType(float32, matrix)> ''
#  |     | | |GpuElemwise{Minimum}[(0, 0)] [@I] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   |GpuElemwise{Mul}[(0, 0)] [@J] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | |GpuElemwise{Add}[(0, 0)] [@K] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | |GpuDot22 [@L] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |GpuFromHost [@M] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | | |Elemwise{Composite{Cast{float32}((i0 * i1))}} [@N] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |HostFromGpu [@O] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   | |GpuElemwise{Minimum}[(0, 0)] [@P] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   |GpuElemwise{Mul}[(0, 0)] [@Q] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | |GpuElemwise{Add}[(0, 0)] [@R] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | |GpuDot22 [@S] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |GpuFromHost [@T] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | | |Elemwise{Composite{Cast{float32}((i0 * i1))}}[(0, 0)] [@U] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |HostFromGpu [@V] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   | |GpuElemwise{Minimum}[(0, 0)] [@W] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |GpuElemwise{Mul}[(0, 0)] [@X] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   | |GpuElemwise{Add}[(0, 0)] [@Y] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   | | |GpuDot22 [@Z] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   | | | |GpuFromHost [@BA] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   | | | | |input_seq [@BB] <TensorType(float32, matrix)>
#  |     | |   | | | |   |   | | | |   |   | | | |W [@BC] <CudaNdarrayType(float32, matrix)>
#  |     | |   | | | |   |   | | | |   |   | | |GpuDimShuffle{x,0} [@BD] <CudaNdarrayType(float32, row)> ''
#  |     | |   | | | |   |   | | | |   |   | |   |b [@BE] <CudaNdarrayType(float32, vector)>
#  |     | |   | | | |   |   | | | |   |   | |GpuFromHost [@BF] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |   |Elemwise{Cast{float32}} [@BG] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |     |Elemwise{gt,no_inplace} [@BH] <TensorType(int8, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |       |HostFromGpu [@BI] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |       | |GpuElemwise{Add}[(0, 0)] [@Y] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |       |TensorConstant{(1, 1) of 0} [@BJ] <TensorType(int8, (True, True))>
#  |     | |   | | | |   |   | | | |   |   |CudaNdarrayConstant{[[ 20.]]} [@BK] <CudaNdarrayType(float32, (True, True))>
#  |     | |   | | | |   |   | | | |   |InplaceDimShuffle{x,0} [@BL] <TensorType(int64, row)> ''
#  |     | |   | | | |   |   | | | |     |RandomFunction{binomial}.1 [@BM] <TensorType(int64, vector)> ''
#  |     | |   | | | |   |   | | | |       |<RandomStateType> [@BN] <RandomStateType>
#  |     | |   | | | |   |   | | | |       |TensorConstant{(1,) of 2048} [@BO] <TensorType(int32, vector)>
#  |     | |   | | | |   |   | | | |       |TensorConstant{1} [@BP] <TensorType(int8, scalar)>
#  |     | |   | | | |   |   | | | |       |HostFromGpu [@BQ] <TensorType(float32, scalar)> ''
#  |     | |   | | | |   |   | | | |         |GpuElemwise{Sub}[(0, 1)] [@BR] <CudaNdarrayType(float32, scalar)> ''
#  |     | |   | | | |   |   | | | |           |CudaNdarrayConstant{1.0} [@BS] <CudaNdarrayType(float32, scalar)>
#  |     | |   | | | |   |   | | | |           |GpuFromHost [@BT] <CudaNdarrayType(float32, scalar)> ''
#  |     | |   | | | |   |   | | | |             |dropoutRate [@BU] <TensorType(float32, scalar)>
#  |     | |   | | | |   |   | | | |W [@BV] <CudaNdarrayType(float32, matrix)>
#  |     | |   | | | |   |   | | |GpuDimShuffle{x,0} [@BW] <CudaNdarrayType(float32, row)> ''
#  |     | |   | | | |   |   | |   |b [@BX] <CudaNdarrayType(float32, vector)>
#  |     | |   | | | |   |   | |GpuFromHost [@BY] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   |   |Elemwise{Cast{float32}} [@BZ] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   |     |Elemwise{gt,no_inplace} [@CA] <TensorType(int8, matrix)> ''
#  |     | |   | | | |   |   |       |HostFromGpu [@CB] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   |       | |GpuElemwise{Add}[(0, 0)] [@R] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   |       |TensorConstant{(1, 1) of 0} [@BJ] <TensorType(int8, (True, True))>
#  |     | |   | | | |   |   |CudaNdarrayConstant{[[ 20.]]} [@BK] <CudaNdarrayType(float32, (True, True))>
#  |     | |   | | | |   |InplaceDimShuffle{x,0} [@CC] <TensorType(int64, row)> ''
#  |     | |   | | | |     |RandomFunction{binomial}.1 [@CD] <TensorType(int64, vector)> ''
#  |     | |   | | | |       |<RandomStateType> [@CE] <RandomStateType>
#  |     | |   | | | |       |TensorConstant{(1,) of 2048} [@BO] <TensorType(int32, vector)>
#  |     | |   | | | |       |TensorConstant{1} [@BP] <TensorType(int8, scalar)>
#  |     | |   | | | |       |HostFromGpu [@BQ] <TensorType(float32, scalar)> ''
#  |     | |   | | | |W [@CF] <CudaNdarrayType(float32, matrix)>
#  |     | |   | | |GpuDimShuffle{x,0} [@CG] <CudaNdarrayType(float32, row)> ''
#  |     | |   | |   |b [@CH] <CudaNdarrayType(float32, vector)>
#  |     | |   | |GpuFromHost [@CI] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   |   |Elemwise{Cast{float32}} [@CJ] <TensorType(float32, matrix)> ''
#  |     | |   |     |Elemwise{gt,no_inplace} [@CK] <TensorType(int8, matrix)> ''
#  |     | |   |       |HostFromGpu [@CL] <TensorType(float32, matrix)> ''
#  |     | |   |       | |GpuElemwise{Add}[(0, 0)] [@K] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   |       |TensorConstant{(1, 1) of 0} [@BJ] <TensorType(int8, (True, True))>
#  |     | |   |CudaNdarrayConstant{[[ 20.]]} [@BK] <CudaNdarrayType(float32, (True, True))>
#  |     | |InplaceDimShuffle{x,0} [@CM] <TensorType(int64, row)> ''
#  |     |   |RandomFunction{binomial}.1 [@CN] <TensorType(int64, vector)> ''
#  |     |     |<RandomStateType> [@CO] <RandomStateType>
#  |     |     |TensorConstant{(1,) of 2048} [@BO] <TensorType(int32, vector)>
#  |     |     |TensorConstant{1} [@BP] <TensorType(int8, scalar)>
#  |     |     |HostFromGpu [@BQ] <TensorType(float32, scalar)> ''
#  |     |MakeVector [@CP] <TensorType(int64, vector)> ''
#  |       |Elemwise{int_div,no_inplace} [@CQ] <TensorType(int64, scalar)> ''
#  |       | |Shape_i{0} [@CR] <TensorType(int64, scalar)> ''
#  |       | | |input_seq [@BB] <TensorType(float32, matrix)>
#  |       | |TensorConstant{10} [@CS] <TensorType(int64, scalar)>
#  |       |TensorConstant{10} [@CS] <TensorType(int64, scalar)>
#  |       |Shape_i{1} [@CT] <TensorType(int64, scalar)> ''
#  |         |W [@CF] <CudaNdarrayType(float32, matrix)>
#  |Shape_i{0} [@CU] <TensorType(int64, scalar)> ''
#  | |W_ff [@CV] <CudaNdarrayType(float32, matrix)>
#  |Shape_i{1} [@CW] <TensorType(int64, scalar)> ''
#    |W_ff [@CV] <CudaNdarrayType(float32, matrix)>
#
# Storage map footprint:
#  - GpuSubtensor{::int64}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Constant{9}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - Elemwise{Composite{(((i0 - i1) - i2) + i3)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDot22.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - HostFromGpu.0, Shape: (1,), ElemSize: 4 Byte(s), TotalSize: 4.0 Byte(s)
#  - Elemwise{switch,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuSplit{2}.0, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - Shape_i{1}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((i0 - i1) - i2)}(i0, i1, i2) + i3), i4, i5, Composite{((i0 - i1) - i2)}(i0, i1, i2), i3), i4, i6), i5), i4), i4, Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((i0 - i1) - i2)}(i0, i1, i2) + i3), i4, i5, Composite{((i0 - i1) - i2)}(i0, i1, i2), i3), i4, i6), i5))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuDot22.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSplit{2}.0, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuDimShuffle{x,0}.0, Shape: (1, 2048), ElemSize: 4 Byte(s), TotalSize: 8192 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4), i6, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5))}}[(0, 6)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - Elemwise{Composite{(i0 * i1 * Cast{float32}((Cast{float64}(i2) * i3)))}}[(0, 2)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.4, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{(i0 * i1 * Cast{float32}((Cast{float64}(i2) * i3)))}}[(0, 2)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - Shape_i{0}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1, i3), i2), i1), i1, Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1, i3), i2))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{x,0}.0, Shape: (1, 2048), ElemSize: 4 Byte(s), TotalSize: 8192 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((i0 - i1) - i2)}(i0, i1, i2) + i3), i4, i5, Composite{((i0 - i1) - i2)}(i0, i1, i2), i3), i4, i6), i5), i4), i4, Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((i0 - i1) - i2)}(i0, i1, i2) + i3), i4, i5, Composite{((i0 - i1) - i2)}(i0, i1, i2), i3), i4, i6), i5))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - forall_inplace,gpu,scan_fn}.0, Shape: (58, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2375680 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{InplaceInc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - Shape_i{0}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - Shape_i{0}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7) + i8), i5, i9, Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7), i8), i5), i9), i5), i10), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7) + i8), i5, i9, Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7), i8), i5), i9), i5), i10)}}[(0, 2)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{int64}.0, Shape: (1024,), ElemSize: 4 Byte(s), TotalSize: 4096 Byte(s)
#  - Shape_i{1}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuIncSubtensor{Inc;::int64}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - RandomFunction{binomial}.0, ElemSize: 64 Byte(s)
#  - TensorConstant{10}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Shape_i{1}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - GpuSubtensor{int64}.0, Shape: (1024,), ElemSize: 4 Byte(s), TotalSize: 4096 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - <theano.tensor.basic.Eye object at 0x7f7dda050b90>.0, Shape: (7, 7), ElemSize: 4 Byte(s), TotalSize: 196 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.14, Shape: (10, 57, 30), ElemSize: 4 Byte(s), TotalSize: 68400 Byte(s)
#  - Elemwise{Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2 + i3), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), i4, maximum((i5 + i6), i2)))}(i0, i1, (i2 - i3), i4, i5, i6, i7), i1, i8, i9), i1, i10), i11), i11, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2 + i3), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), i4, maximum((i5 + i6), i2)))}(i0, i1, (i2 - i3), i4, i5, i6, i7), i1, i8, i9), i1, i10))}}[(0, 3)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4), i6, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{EQ}.0, Shape: (570, 2048), ElemSize: 1 Byte(s), TotalSize: 1167360 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, Switch(AND(LT(Composite{(i0 + (i1 - i2))}(i2, i3, i4), i1), GT(i5, i1)), i6, minimum(Composite{(i0 + (i1 - i2))}(i2, i3, i4), i7)))}}[(0, 2)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (58, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2375680 Byte(s)
#  - GpuDimShuffle{0,2,1}.0, Shape: (10, 30, 57), ElemSize: 4 Byte(s), TotalSize: 68400 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, maximum(minimum((i2 + (i3 - i4)), i5), i6))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{(i0 * i1 * Cast{float32}((Cast{float64}(i2) * i3)))}}[(0, 2)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Constant{0}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.5, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.9, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuElemwise{Add}[(0, 0)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.6, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4), i6, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{0,2,1}.0, Shape: (66, 2048, 10), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSplit{2}.0, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.7, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuReshape{2}.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{:int64:}.0, Shape: (1, 2048, 1024), ElemSize: 4 Byte(s), TotalSize: 8388608 Byte(s)
#  - Reshape{3}.0, Shape: (57, 10, 2048), ElemSize: 8 Byte(s), TotalSize: 9338880 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuFromHost.0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSplit{2}.1, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - TensorConstant{2048}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{LE((i0 - i1), i2)}}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuReshape{2}.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - TensorConstant{1024}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.13, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (91, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - GpuSubtensor{:int64:}.0, Shape: (1, 1024, 1024), ElemSize: 4 Byte(s), TotalSize: 4194304 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Cast{float64}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(minimum((i2 + i3), i4), i5))}(i0, i1, i2, i3, i4, i5), i1, i6), i1), i7, Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(minimum((i2 + i3), i4), i5))}(i0, i1, i2, i3, i4, i5), i1, i6))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, minimum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4), i1), i1, Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, minimum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.12, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.8, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.15, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.10, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - TensorConstant{-1}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDot22.0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - GpuReshape{2}.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, Switch(AND(LT((i2 + i3 + i4), i1), GT(i5, i1)), (i2 - i6), minimum((i2 + i3 + i4), i7)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.16, Shape: (91, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, maximum(i2, (i3 - i4)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{ge,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuIncSubtensor{InplaceInc;int64::}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.7, Shape: (10, 57, 30), ElemSize: 4 Byte(s), TotalSize: 68400 Byte(s)
#  - Elemwise{Composite{((-i0) - i1)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Subtensor{int64:int64:int64}.0, Shape: (10, 7), ElemSize: 4 Byte(s), TotalSize: 280 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{maximum(maximum(((i0 - Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Switch(i1, (i2 - i3), i4) + i3), Composite{((((i0 - i1) - i2) // i2) + i2)}(Switch(i1, (i2 - i3), i4), i5, i3), i6, i3), i6, (Switch(i1, (i2 - i3), i4) + i3), i3), i6), Composite{Switch(LT(i0, i1), i1, i0)}((Switch(i1, (i2 - i3), i4) + i3), i6)), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Switch(i1, (i2 - i3), i4) + i3), Composite{((((i0 - i1) - i2) // i2) + i2)}(Switch(i1, (i2 - i3), i4), i5, i3), i6, i3), i6, (Switch(i1, (i2 - i3), i4) + i3), i3), i6), Composite{Switch(LT(i0, i1), i1, i0)}((Switch(i1, (i2 - i3), i4) + i3), i6))) + i3), i3), maximum(maximum(((i0 - Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Switch(i7, (i2 - i3), i8) + i3), Composite{((((i0 - i1) - i2) // i2) + i2)}(Switch(i7, (i2 - i3), i8), i9, i3), i6, i3), i6, (Switch(i7, (i2 - i3), i8) + i3), i3), i6), Composite{Switch(LT(i0, i1), i1, i0)}((Switch(i7, (i2 - i3), i8) + i3), i6)), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Switch(i7, (i2 - i3), i8) + i3), Composite{((((i0 - i1) - i2) // i2) + i2)}(Switch(i7, (i2 - i3), i8), i9, i3), i6, i3), i6, (Switch(i7, (i2 - i3), i8) + i3), i3), i6), Composite{Switch(LT(i0, i1), i1, i0)}((Switch(i7, (i2 - i3), i8) + i3), i6))) + i3), i3), maximum(((i0 - i10) + i3), i3)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSplit{2}.1, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}}[(0, 2)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{(((Switch(i0, (i1 + i2), i1) - i3) - i4) + i5)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuFromHost.0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuSplit{2}.1, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{Cast{float32}((i0 * i1))}}.0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - GpuDimShuffle{x,0}.0, Shape: (1, 1024), ElemSize: 4 Byte(s), TotalSize: 4096 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, maximum(minimum((i2 + i3 + i4), i5), i6))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - Elemwise{Composite{(i0 * i1 * Cast{float32}((Cast{float64}(i2) * i3)))}}[(0, 2)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.10, Shape: (10, 57, 30), ElemSize: 4 Byte(s), TotalSize: 68400 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDot22.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{switch,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.13, Shape: (91, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (91, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (11, 2048, 30), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, Switch(AND(LT((i2 + i3 + i4), i1), GT(i5, i1)), i6, minimum((i2 + i3 + i4), i7)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{((-i0) - i1)}}[(0, 0)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{switch,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuElemwise{Add}[(0, 0)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuFromHost.0, Shape: (1,), ElemSize: 4 Byte(s), TotalSize: 4.0 Byte(s)
#  - GpuIncSubtensor{InplaceInc;int64::}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuElemwise{Add}[(0, 0)].0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.12, Shape: (10, 57, 30), ElemSize: 4 Byte(s), TotalSize: 68400 Byte(s)
#  - Elemwise{lt,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuElemwise{Minimum}[(0, 0)].0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - MakeVector.0, Shape: (3,), ElemSize: 8 Byte(s), TotalSize: 24 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{(((i0 - i1) - i2) + i3)}}[(0, 0)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Cast{float64}}.0, Shape: (1, 7), ElemSize: 8 Byte(s), TotalSize: 56 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i2) + i2)}(i1, i2, i3), i4, i3), i4, i0, i3), i4), i5), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i2) + i2)}(i1, i2, i3), i4, i3), i4, i0, i3), i4), i5)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.3, Shape: (10, 57, 30), ElemSize: 4 Byte(s), TotalSize: 68400 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.5, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuElemwise{Mul}[(0, 0)].0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - HostFromGpu.0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{switch,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{InplaceInc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
# ...
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(i0, Switch(LT((i1 + (i2 - i3)), i4), i4, (i1 + (i2 - i3))), Switch(LT(i1, (i2 - i3)), i1, (i2 - i3)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSplit{2}.1, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Constant{1}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1), i2), i1), i3), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1), i2), i1), i3)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{:int64:}.0, Shape: (1, 1024, 1024), ElemSize: 4 Byte(s), TotalSize: 4194304 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{(i0 * i1 * Cast{float32}((Cast{float64}(i2) * i3)))}}[(0, 2)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{:int64:}.0, Shape: (1, 1024), ElemSize: 4 Byte(s), TotalSize: 4096 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.0, Shape: (1, 30), ElemSize: 4 Byte(s), TotalSize: 120 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, Switch(AND(LT((i2 + i3 + i4), i1), GT(i5, i1)), i6, minimum((i2 + i3 + i4), i7)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT((i0 + i1), i2), i2, (i0 + i1))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.3, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{:int64:}.0, Shape: (1, 1024), ElemSize: 4 Byte(s), TotalSize: 4096 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSplit{2}.1, Shape: (10, 66, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.11, Shape: (10, 57, 30), ElemSize: 4 Byte(s), TotalSize: 68400 Byte(s)
#  - HostFromGpu.0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (91, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuCAReduce{add}{1,0}.0, Shape: (2048,), ElemSize: 4 Byte(s), TotalSize: 8192 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Cast{float32}((i0 * i1))}}[(0, 0)].0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{EQ}.0, Shape: (570, 2048), ElemSize: 1 Byte(s), TotalSize: 1167360 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{0,2,1}.0, Shape: (10, 2048, 91), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,scan_fn}.0, Shape: (58, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2375680 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1), i2), i1), i3), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1), i2), i1), i3)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7) + i8), i5, i9, Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7), i8), i5), i9), i5), i10), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7) + i8), i5, i9, Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7), i8), i5), i9), i5), i10)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.2, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Cast{float32}}.0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{maximum,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuFromHost.0, Shape: (570, 560), ElemSize: 4 Byte(s), TotalSize: 1276800 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSplit{2}.0, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (67, 1024), ElemSize: 4 Byte(s), TotalSize: 274432 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - TensorConstant{-11}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (57, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - GpuFromHost.0, Shape: (570, 2048), ElemSize: 4 Byte(s), TotalSize: 4669440 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuReshape{2}.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.6, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#
# HINT: Re-running with most Theano optimization disabled could give you a back-trace of when this node was created. This can be done with by setting the Theano flag 'optimizer=fast_compile'. If that does not work, Theano optimizations can be disabled with 'optimizer=None'.

# %%
x = batch_dict[lp_lens[5]][1][0:10]
x = x.reshape(x.shape[0] * x.shape[1], x.shape[2])

output = network.trainer(x, batch_dict[lp_lens[5]][0][0:10], .1)

print output
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-17-0763da38dbf5> in <module>()
#       2 x = x.reshape(x.shape[0] * x.shape[1], x.shape[2])
#       3
# ----> 4 output = network.trainer(x, batch_dict[lp_lens[5]][0][0:10], .1)
#       5
#       6 print output
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     604                         self.fn.nodes[self.fn.position_of_error],
#     605                         self.fn.thunks[self.fn.position_of_error],
# --> 606                         storage_map=self.fn.storage_map)
#     607                 else:
#     608                     # For the c linker We don't have access from
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# MemoryError: Error allocating 281018368 bytes of device memory (out of memory).
# Apply node that caused the error: GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0, Shape_i{1}.0)
# Inputs types: [CudaNdarrayType(float32, scalar), TensorType(int64, scalar), TensorType(int64, scalar), TensorType(int64, scalar)]
# Inputs shapes: [(), (), (), ()]
# Inputs strides: [(), (), (), ()]
# Inputs values: [<CudaNdarray object at 0x7f7b78f53370>, array(67), array(1024), array(1024)]
#
# Debugprint of the apply node:
# GpuAlloc{memset_0=True} [@A] <CudaNdarrayType(float32, 3D)> ''
#  |CudaNdarrayConstant{0.0} [@B] <CudaNdarrayType(float32, scalar)>
#  |Elemwise{add,no_inplace} [@C] <TensorType(int64, scalar)> ''
#  | |TensorConstant{1} [@D] <TensorType(int64, scalar)>
#  | |Shape_i{0} [@E] <TensorType(int64, scalar)> ''
#  |   |Reshape{3} [@F] <TensorType(float64, 3D)> ''
#  |     |Elemwise{mul,no_inplace} [@G] <TensorType(float64, matrix)> ''
#  |     | |HostFromGpu [@H] <TensorType(float32, matrix)> ''
#  |     | | |GpuElemwise{Minimum}[(0, 0)] [@I] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   |GpuElemwise{Mul}[(0, 0)] [@J] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | |GpuElemwise{Add}[(0, 0)] [@K] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | |GpuDot22 [@L] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |GpuFromHost [@M] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | | |Elemwise{Composite{Cast{float32}((i0 * i1))}} [@N] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |HostFromGpu [@O] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   | |GpuElemwise{Minimum}[(0, 0)] [@P] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   |GpuElemwise{Mul}[(0, 0)] [@Q] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | |GpuElemwise{Add}[(0, 0)] [@R] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | |GpuDot22 [@S] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |GpuFromHost [@T] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | | |Elemwise{Composite{Cast{float32}((i0 * i1))}}[(0, 0)] [@U] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |HostFromGpu [@V] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   | |GpuElemwise{Minimum}[(0, 0)] [@W] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |GpuElemwise{Mul}[(0, 0)] [@X] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   | |GpuElemwise{Add}[(0, 0)] [@Y] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   | | |GpuDot22 [@Z] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   | | | |GpuFromHost [@BA] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   | | | | |input_seq [@BB] <TensorType(float32, matrix)>
#  |     | |   | | | |   |   | | | |   |   | | | |W [@BC] <CudaNdarrayType(float32, matrix)>
#  |     | |   | | | |   |   | | | |   |   | | |GpuDimShuffle{x,0} [@BD] <CudaNdarrayType(float32, row)> ''
#  |     | |   | | | |   |   | | | |   |   | |   |b [@BE] <CudaNdarrayType(float32, vector)>
#  |     | |   | | | |   |   | | | |   |   | |GpuFromHost [@BF] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |   |Elemwise{Cast{float32}} [@BG] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |     |Elemwise{gt,no_inplace} [@BH] <TensorType(int8, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |       |HostFromGpu [@BI] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |       | |GpuElemwise{Add}[(0, 0)] [@Y] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   | | | |   |   |       |TensorConstant{(1, 1) of 0} [@BJ] <TensorType(int8, (True, True))>
#  |     | |   | | | |   |   | | | |   |   |CudaNdarrayConstant{[[ 20.]]} [@BK] <CudaNdarrayType(float32, (True, True))>
#  |     | |   | | | |   |   | | | |   |InplaceDimShuffle{x,0} [@BL] <TensorType(int64, row)> ''
#  |     | |   | | | |   |   | | | |     |RandomFunction{binomial}.1 [@BM] <TensorType(int64, vector)> ''
#  |     | |   | | | |   |   | | | |       |<RandomStateType> [@BN] <RandomStateType>
#  |     | |   | | | |   |   | | | |       |TensorConstant{(1,) of 2048} [@BO] <TensorType(int32, vector)>
#  |     | |   | | | |   |   | | | |       |TensorConstant{1} [@BP] <TensorType(int8, scalar)>
#  |     | |   | | | |   |   | | | |       |HostFromGpu [@BQ] <TensorType(float32, scalar)> ''
#  |     | |   | | | |   |   | | | |         |GpuElemwise{Sub}[(0, 1)] [@BR] <CudaNdarrayType(float32, scalar)> ''
#  |     | |   | | | |   |   | | | |           |CudaNdarrayConstant{1.0} [@BS] <CudaNdarrayType(float32, scalar)>
#  |     | |   | | | |   |   | | | |           |GpuFromHost [@BT] <CudaNdarrayType(float32, scalar)> ''
#  |     | |   | | | |   |   | | | |             |dropoutRate [@BU] <TensorType(float32, scalar)>
#  |     | |   | | | |   |   | | | |W [@BV] <CudaNdarrayType(float32, matrix)>
#  |     | |   | | | |   |   | | |GpuDimShuffle{x,0} [@BW] <CudaNdarrayType(float32, row)> ''
#  |     | |   | | | |   |   | |   |b [@BX] <CudaNdarrayType(float32, vector)>
#  |     | |   | | | |   |   | |GpuFromHost [@BY] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   |   |Elemwise{Cast{float32}} [@BZ] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   |     |Elemwise{gt,no_inplace} [@CA] <TensorType(int8, matrix)> ''
#  |     | |   | | | |   |   |       |HostFromGpu [@CB] <TensorType(float32, matrix)> ''
#  |     | |   | | | |   |   |       | |GpuElemwise{Add}[(0, 0)] [@R] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   | | | |   |   |       |TensorConstant{(1, 1) of 0} [@BJ] <TensorType(int8, (True, True))>
#  |     | |   | | | |   |   |CudaNdarrayConstant{[[ 20.]]} [@BK] <CudaNdarrayType(float32, (True, True))>
#  |     | |   | | | |   |InplaceDimShuffle{x,0} [@CC] <TensorType(int64, row)> ''
#  |     | |   | | | |     |RandomFunction{binomial}.1 [@CD] <TensorType(int64, vector)> ''
#  |     | |   | | | |       |<RandomStateType> [@CE] <RandomStateType>
#  |     | |   | | | |       |TensorConstant{(1,) of 2048} [@BO] <TensorType(int32, vector)>
#  |     | |   | | | |       |TensorConstant{1} [@BP] <TensorType(int8, scalar)>
#  |     | |   | | | |       |HostFromGpu [@BQ] <TensorType(float32, scalar)> ''
#  |     | |   | | | |W [@CF] <CudaNdarrayType(float32, matrix)>
#  |     | |   | | |GpuDimShuffle{x,0} [@CG] <CudaNdarrayType(float32, row)> ''
#  |     | |   | |   |b [@CH] <CudaNdarrayType(float32, vector)>
#  |     | |   | |GpuFromHost [@CI] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   |   |Elemwise{Cast{float32}} [@CJ] <TensorType(float32, matrix)> ''
#  |     | |   |     |Elemwise{gt,no_inplace} [@CK] <TensorType(int8, matrix)> ''
#  |     | |   |       |HostFromGpu [@CL] <TensorType(float32, matrix)> ''
#  |     | |   |       | |GpuElemwise{Add}[(0, 0)] [@K] <CudaNdarrayType(float32, matrix)> ''
#  |     | |   |       |TensorConstant{(1, 1) of 0} [@BJ] <TensorType(int8, (True, True))>
#  |     | |   |CudaNdarrayConstant{[[ 20.]]} [@BK] <CudaNdarrayType(float32, (True, True))>
#  |     | |InplaceDimShuffle{x,0} [@CM] <TensorType(int64, row)> ''
#  |     |   |RandomFunction{binomial}.1 [@CN] <TensorType(int64, vector)> ''
#  |     |     |<RandomStateType> [@CO] <RandomStateType>
#  |     |     |TensorConstant{(1,) of 2048} [@BO] <TensorType(int32, vector)>
#  |     |     |TensorConstant{1} [@BP] <TensorType(int8, scalar)>
#  |     |     |HostFromGpu [@BQ] <TensorType(float32, scalar)> ''
#  |     |MakeVector [@CP] <TensorType(int64, vector)> ''
#  |       |Elemwise{int_div,no_inplace} [@CQ] <TensorType(int64, scalar)> ''
#  |       | |Shape_i{0} [@CR] <TensorType(int64, scalar)> ''
#  |       | | |input_seq [@BB] <TensorType(float32, matrix)>
#  |       | |TensorConstant{10} [@CS] <TensorType(int64, scalar)>
#  |       |TensorConstant{10} [@CS] <TensorType(int64, scalar)>
#  |       |Shape_i{1} [@CT] <TensorType(int64, scalar)> ''
#  |         |W [@CF] <CudaNdarrayType(float32, matrix)>
#  |Shape_i{0} [@CU] <TensorType(int64, scalar)> ''
#  | |W_ff [@CV] <CudaNdarrayType(float32, matrix)>
#  |Shape_i{1} [@CW] <TensorType(int64, scalar)> ''
#    |W_ff [@CV] <CudaNdarrayType(float32, matrix)>
#
# Storage map footprint:
#  - GpuSubtensor{::int64}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Constant{9}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - Elemwise{Composite{(((i0 - i1) - i2) + i3)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDot22.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - HostFromGpu.0, Shape: (1,), ElemSize: 4 Byte(s), TotalSize: 4.0 Byte(s)
#  - Elemwise{switch,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuSplit{2}.0, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - Shape_i{1}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((i0 - i1) - i2)}(i0, i1, i2) + i3), i4, i5, Composite{((i0 - i1) - i2)}(i0, i1, i2), i3), i4, i6), i5), i4), i4, Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((i0 - i1) - i2)}(i0, i1, i2) + i3), i4, i5, Composite{((i0 - i1) - i2)}(i0, i1, i2), i3), i4, i6), i5))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuDot22.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSplit{2}.0, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuDimShuffle{x,0}.0, Shape: (1, 2048), ElemSize: 4 Byte(s), TotalSize: 8192 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4), i6, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5))}}[(0, 6)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - Elemwise{Composite{(i0 * i1 * Cast{float32}((Cast{float64}(i2) * i3)))}}[(0, 2)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.4, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{(i0 * i1 * Cast{float32}((Cast{float64}(i2) * i3)))}}[(0, 2)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - Shape_i{0}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1, i3), i2), i1), i1, Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1, i3), i2))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{x,0}.0, Shape: (1, 2048), ElemSize: 4 Byte(s), TotalSize: 8192 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((i0 - i1) - i2)}(i0, i1, i2) + i3), i4, i5, Composite{((i0 - i1) - i2)}(i0, i1, i2), i3), i4, i6), i5), i4), i4, Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((i0 - i1) - i2)}(i0, i1, i2) + i3), i4, i5, Composite{((i0 - i1) - i2)}(i0, i1, i2), i3), i4, i6), i5))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - forall_inplace,gpu,scan_fn}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{InplaceInc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - Shape_i{0}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - Shape_i{0}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7) + i8), i5, i9, Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7), i8), i5), i9), i5), i10), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7) + i8), i5, i9, Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7), i8), i5), i9), i5), i10)}}[(0, 2)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{int64}.0, Shape: (1024,), ElemSize: 4 Byte(s), TotalSize: 4096 Byte(s)
#  - Shape_i{1}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuIncSubtensor{Inc;::int64}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - RandomFunction{binomial}.0, ElemSize: 64 Byte(s)
#  - TensorConstant{10}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Shape_i{1}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - GpuSubtensor{int64}.0, Shape: (1024,), ElemSize: 4 Byte(s), TotalSize: 4096 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - <theano.tensor.basic.Eye object at 0x7f7dda050b90>.0, Shape: (15, 15), ElemSize: 4 Byte(s), TotalSize: 900 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.14, Shape: (10, 66, 30), ElemSize: 4 Byte(s), TotalSize: 79200 Byte(s)
#  - Elemwise{Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2 + i3), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), i4, maximum((i5 + i6), i2)))}(i0, i1, (i2 - i3), i4, i5, i6, i7), i1, i8, i9), i1, i10), i11), i11, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2 + i3), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), i4, maximum((i5 + i6), i2)))}(i0, i1, (i2 - i3), i4, i5, i6, i7), i1, i8, i9), i1, i10))}}[(0, 3)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4), i6, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{EQ}.0, Shape: (660, 2048), ElemSize: 1 Byte(s), TotalSize: 1351680 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, Switch(AND(LT(Composite{(i0 + (i1 - i2))}(i2, i3, i4), i1), GT(i5, i1)), i6, minimum(Composite{(i0 + (i1 - i2))}(i2, i3, i4), i7)))}}[(0, 2)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuDimShuffle{0,2,1}.0, Shape: (10, 30, 66), ElemSize: 4 Byte(s), TotalSize: 79200 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, maximum(minimum((i2 + (i3 - i4)), i5), i6))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{(i0 * i1 * Cast{float32}((Cast{float64}(i2) * i3)))}}[(0, 2)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Constant{0}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.5, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.9, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuElemwise{Add}[(0, 0)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.6, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4), i6, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{0,2,1}.0, Shape: (66, 2048, 10), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSplit{2}.0, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.7, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuReshape{2}.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{:int64:}.0, Shape: (1, 2048, 1024), ElemSize: 4 Byte(s), TotalSize: 8388608 Byte(s)
#  - Reshape{3}.0, Shape: (66, 10, 2048), ElemSize: 8 Byte(s), TotalSize: 10813440 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSplit{2}.1, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - TensorConstant{2048}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{LE((i0 - i1), i2)}}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuReshape{2}.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - TensorConstant{1024}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.13, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (91, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - GpuSubtensor{:int64:}.0, Shape: (1, 1024, 1024), ElemSize: 4 Byte(s), TotalSize: 4194304 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Cast{float64}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(minimum((i2 + i3), i4), i5))}(i0, i1, i2, i3, i4, i5), i1, i6), i1), i7, Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(minimum((i2 + i3), i4), i5))}(i0, i1, i2, i3, i4, i5), i1, i6))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, minimum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4), i1), i1, Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, minimum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.12, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.8, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.15, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.10, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - TensorConstant{-1}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDot22.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuReshape{2}.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, Switch(AND(LT((i2 + i3 + i4), i1), GT(i5, i1)), (i2 - i6), minimum((i2 + i3 + i4), i7)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.16, Shape: (91, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, maximum(i2, (i3 - i4)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{ge,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuIncSubtensor{InplaceInc;int64::}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.7, Shape: (10, 66, 30), ElemSize: 4 Byte(s), TotalSize: 79200 Byte(s)
#  - Elemwise{Composite{((-i0) - i1)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Subtensor{int64:int64:int64}.0, Shape: (10, 15), ElemSize: 4 Byte(s), TotalSize: 600 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{maximum(maximum(((i0 - Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Switch(i1, (i2 - i3), i4) + i3), Composite{((((i0 - i1) - i2) // i2) + i2)}(Switch(i1, (i2 - i3), i4), i5, i3), i6, i3), i6, (Switch(i1, (i2 - i3), i4) + i3), i3), i6), Composite{Switch(LT(i0, i1), i1, i0)}((Switch(i1, (i2 - i3), i4) + i3), i6)), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Switch(i1, (i2 - i3), i4) + i3), Composite{((((i0 - i1) - i2) // i2) + i2)}(Switch(i1, (i2 - i3), i4), i5, i3), i6, i3), i6, (Switch(i1, (i2 - i3), i4) + i3), i3), i6), Composite{Switch(LT(i0, i1), i1, i0)}((Switch(i1, (i2 - i3), i4) + i3), i6))) + i3), i3), maximum(maximum(((i0 - Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Switch(i7, (i2 - i3), i8) + i3), Composite{((((i0 - i1) - i2) // i2) + i2)}(Switch(i7, (i2 - i3), i8), i9, i3), i6, i3), i6, (Switch(i7, (i2 - i3), i8) + i3), i3), i6), Composite{Switch(LT(i0, i1), i1, i0)}((Switch(i7, (i2 - i3), i8) + i3), i6)), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Switch(i7, (i2 - i3), i8) + i3), Composite{((((i0 - i1) - i2) // i2) + i2)}(Switch(i7, (i2 - i3), i8), i9, i3), i6, i3), i6, (Switch(i7, (i2 - i3), i8) + i3), i3), i6), Composite{Switch(LT(i0, i1), i1, i0)}((Switch(i7, (i2 - i3), i8) + i3), i6))) + i3), i3), maximum(((i0 - i10) + i3), i3)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSplit{2}.1, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}}[(0, 2)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{(((Switch(i0, (i1 + i2), i1) - i3) - i4) + i5)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuSplit{2}.1, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{Cast{float32}((i0 * i1))}}.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuDimShuffle{x,0}.0, Shape: (1, 1024), ElemSize: 4 Byte(s), TotalSize: 4096 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, maximum(minimum((i2 + i3 + i4), i5), i6))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - Elemwise{Composite{(i0 * i1 * Cast{float32}((Cast{float64}(i2) * i3)))}}[(0, 2)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.10, Shape: (10, 66, 30), ElemSize: 4 Byte(s), TotalSize: 79200 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDot22.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{switch,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.13, Shape: (91, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (91, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (11, 2048, 30), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, Switch(AND(LT((i2 + i3 + i4), i1), GT(i5, i1)), i6, minimum((i2 + i3 + i4), i7)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{((-i0) - i1)}}[(0, 0)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{switch,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuElemwise{Add}[(0, 0)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuFromHost.0, Shape: (1,), ElemSize: 4 Byte(s), TotalSize: 4.0 Byte(s)
#  - GpuIncSubtensor{InplaceInc;int64::}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuElemwise{Add}[(0, 0)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.12, Shape: (10, 66, 30), ElemSize: 4 Byte(s), TotalSize: 79200 Byte(s)
#  - Elemwise{lt,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuElemwise{Minimum}[(0, 0)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - MakeVector.0, Shape: (3,), ElemSize: 8 Byte(s), TotalSize: 24 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{(((i0 - i1) - i2) + i3)}}[(0, 0)].0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Cast{float64}}.0, Shape: (1, 15), ElemSize: 8 Byte(s), TotalSize: 120 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i2) + i2)}(i1, i2, i3), i4, i3), i4, i0, i3), i4), i5), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i2) + i2)}(i1, i2, i3), i4, i3), i4, i0, i3), i4), i5)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.3, Shape: (10, 66, 30), ElemSize: 4 Byte(s), TotalSize: 79200 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.5, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuElemwise{Mul}[(0, 0)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{switch,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{InplaceInc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
# ...
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(i0, Switch(LT((i1 + (i2 - i3)), i4), i4, (i1 + (i2 - i3))), Switch(LT(i1, (i2 - i3)), i1, (i2 - i3)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSplit{2}.1, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Constant{1}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1), i2), i1), i3), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1), i2), i1), i3)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{:int64:}.0, Shape: (1, 1024, 1024), ElemSize: 4 Byte(s), TotalSize: 4194304 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{(i0 * i1 * Cast{float32}((Cast{float64}(i2) * i3)))}}[(0, 2)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{:int64:}.0, Shape: (1, 1024), ElemSize: 4 Byte(s), TotalSize: 4096 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.0, Shape: (1, 30), ElemSize: 4 Byte(s), TotalSize: 120 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, Switch(AND(LT((i2 + i3 + i4), i1), GT(i5, i1)), i6, minimum((i2 + i3 + i4), i7)))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{Composite{Switch(LT((i0 + i1), i2), i2, (i0 + i1))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.3, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{:int64:}.0, Shape: (1, 1024), ElemSize: 4 Byte(s), TotalSize: 4096 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{sub,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSplit{2}.1, Shape: (10, 66, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - for{gpu,scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.11, Shape: (10, 66, 30), ElemSize: 4 Byte(s), TotalSize: 79200 Byte(s)
#  - HostFromGpu.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (91, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuCAReduce{add}{1,0}.0, Shape: (2048,), ElemSize: 4 Byte(s), TotalSize: 8192 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Cast{float32}((i0 * i1))}}[(0, 0)].0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuDimShuffle{1,0,2}.0, Shape: (66, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2703360 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{EQ}.0, Shape: (660, 2048), ElemSize: 1 Byte(s), TotalSize: 1351680 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuDimShuffle{0,2,1}.0, Shape: (10, 2048, 91), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - Elemwise{le,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,scan_fn}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuSubtensor{::int64}.0, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1), i2), i1), i3), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(i0, i1, i2), i1), i2), i1), i3)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7) + i8), i5, i9, Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7), i8), i5), i9), i5), i10), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 + i3 + i4), i0)}((Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7) + i8), i5, i9, Composite{((Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}(i0, Composite{((((i0 - i1) - i2) // i3) + i2)}(i1, i2, i3, i4), i5, i3), i5, i0, i3), i5), i6) - i7) - i4)}(i0, i1, i2, i3, i4, i5, i6, i7), i8), i5), i9), i5), i10)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.2, Shape: (92, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 3768320 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 2048), ElemSize: 4 Byte(s), TotalSize: 7454720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{Cast{float32}}.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuSubtensor{int64:int64:int64}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - Elemwise{maximum,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuFromHost.0, Shape: (660, 560), ElemSize: 4 Byte(s), TotalSize: 1478400 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - ScalarFromTensor.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuSplit{2}.0, Shape: (10, 91, 1024), ElemSize: 4 Byte(s), TotalSize: 3727360 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (67, 1024), ElemSize: 4 Byte(s), TotalSize: 274432 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - TensorConstant{-11}, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuAlloc{memset_0=True}.0, Shape: (66, 10, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuFromHost.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuReshape{2}.0, Shape: (660, 2048), ElemSize: 4 Byte(s), TotalSize: 5406720 Byte(s)
#  - forall_inplace,gpu,grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn&grad_of_scan_fn}.6, Shape: (67, 10, 1024), ElemSize: 4 Byte(s), TotalSize: 2744320 Byte(s)
#  - GpuIncSubtensor{Inc;int64::}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#  - GpuIncSubtensor{Inc;:int64:}.0, Shape: (10, 91, 30), ElemSize: 4 Byte(s), TotalSize: 109200 Byte(s)
#
# HINT: Re-running with most Theano optimization disabled could give you a back-trace of when this node was created. This can be done with by setting the Theano flag 'optimizer=fast_compile'. If that does not work, Theano optimizations can be disabled with 'optimizer=None'.

# %%
# create network
try:
    last_good = -1
    restart = False
    #log_file = file('/var/www/html/status.html', 'a')
    log_file = file('status.html', 'a')
    duration = time.time()
    if last_good == -1:
        network = net.create_network(560, len(alphabet)+1, .0005, .75)        #x3 for the window
        log_it(log_file, etc='created Network - num samples:' + str(len(samples)) + '\tDuration: ' + str(time.time()-duration))
    else:
        picklePath = 'saved_models_batch/' + str(last_good) + '.pkl'
        print 'loading from', picklePath
        network = net.load_network(picklePath, 560, len(alphabet)+1, .0005, .75)        #x3 for the window
        log_it(log_file, etc='loaded Network - num samples:' + str(len(samples)) + '\tDuration: ' + str(time.time()-duration))
    log_file.close()

    if last_good == -1:
        error_avg_epoch = 0.0
        duration = time.time()

        # For each bucket of samples
        for length in lp_lens:

            sequence_length = length

            for i in np.arange(0, math.ceil(sequence_length/batch_size)):
                duration2 = time.time()

                temp_model = network.get_parameters()

                num_samples_in_selected = batch_dict[sequence_length][1].shape[0] - (i*batch_size)    # get the number of available samples in the bucket

                if num_samples_in_selected < batch_size:
                    minibatch_start = (i*batch_size)
                    minibatch_end = (i*batch_size) + num_samples_in_selected
                else:
                    minibatch_start = i * batch_size
                    minibatch_end = minibatch_start + batch_size
                    
                print 'Shape:', batch_dict[sequence_length][1][minibatch_start:minibatch_end, :, :].shape

                cost, _ = network.trainer(batch_dict[sequence_length][1][minibatch_start:minibatch_end, :, :], batch_dict[sequence_length][0][minibatch_start:minibatch_end, :])

                if math.isnan(cost) or math.isinf(cost):
                    restart = True
                    network.set_parameters(temp_model)
                    #raw_input("Hit NAN on sequential first-round input!! Very bad...")
                    print("Hit NAN on sequential first-round input!! Very bad...")
                    break

                error_avg_epoch += cost
                print '\t', cost, minibatch_end-minibatch_start, time.time()-duration2




    # Start a new Epoch
    for epoch in np.arange(last_good+1, 100000):

        error_avg_epoch = 0.0
        duration = time.time()

        # For each desired mini-batch
        for minibatch in np.arange(epoch_size):
            temp_model = network.get_parameters()
            
            duration2 = time.time()

            sequence_length_index = rng.randint(0, len(lp_lens))                                # randomly select a bucket of samples to create a mini-batch from
            sequence_length = lp_lens[sequence_length_index]

            num_samples_in_selected = batch_dict[sequence_length][1].shape[0]    # get the number of available samples in the bucket
            
            if False: minibatch_start = 0; minibatch_end = batch_size
            elif num_samples_in_selected < batch_size:
                minibatch_start = 0
                minibatch_end = num_samples_in_selected
            else:
                minibatch_start = rng.randint(0, len(lp_lens))
                minibatch_end = minibatch_start + batch_size

            cost, _ = network.trainer(batch_dict[sequence_length][1][minibatch_start:minibatch_end, :, :], batch_dict[sequence_length][0][minibatch_start:minibatch_end, :])

            if math.isnan(cost) or math.isinf(cost):
                #restart = True
                #break
                network.set_parameters(temp_model)
                print "hit nan - undoing batch"

            error_avg_epoch += cost
            print '\t', cost, minibatch_end-minibatch_start, time.time()-duration2


        log_file = file('status.html', 'a') #file('/var/www/html/status.html', 'a')
        if not restart:

            print 'Avg. Error:', error_avg_epoch, ' || over', batch_dict[sequence_length][1].shape, '\tsamples\t | in %.3fs' % (time.time() - duration)
            
            pred = network.tester(visual_samples_x)[0]
            for i in np.arange(2):
                log_it(log_file, etc='\t' + seq_to_str(visual_sample_y[i]) + ' || ' + seq_to_str([np.argmax(x) for x in pred[i]]))

            if epoch % 10: #epoch_size:
                dumpPath = 'saved_models_batch/' + str(epoch) + '.pkl'
                print 'Saving to: ', dumpPath
                net.dump_network(dumpPath)

                last_good = epoch

        else:
            log_it(log_file, nan=True)
            restart = False

            duration = time.time()
            picklePath = 'saved_models_batch/' + str(last_good) + '.pkl'
            print 'loading from', picklePath
            network = net.load_network(picklePath, 560, len(alphabet)+1, .0005, .75)        #x3 for the window
            log_it(log_file, etc='loaded Network - num samples:' + str(len(samples)) + '\tDuration: ' + str(time.time()-duration))
        log_file.close()


except KeyboardInterrupt:
    pass

# shuffle lp_lens

# take lp_lens[0] as length

    # random from [0, batch_dict[length]-batch_size]

    # batch train on the random slice

    # every Xth training batch, save model, shuffle
